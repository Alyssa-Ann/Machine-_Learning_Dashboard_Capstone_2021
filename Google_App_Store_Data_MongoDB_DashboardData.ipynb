# %%
import pandas as pd
from path import Path
import numpy as np
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
import certifi
ca = certifi.where()

# %%
pymongo.version
# Out:
# '3.12.0'

# %%
client = pymongo.MongoClient("mongodb+srv://mihir123:mihir123@cluster0.yecsu.mongodb.net/test?retryWrites=true&w=majority", tlsCAFile=ca)

# %%
client.list_database_names()
# Out:
# ['Google_App_Store_Data', 'admin', 'local']

# %%
app_data = client["Google_App_Store_Data"]

# %%
mycollection = app_data["Google_App_Store_Data"]

# %%
print(mycollection)
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.yecsu.mongodb.net:27017', 'cluster0-shard-00-01.yecsu.mongodb.net:27017', 'cluster0-shard-00-02.yecsu.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-1vubxh-shard-0', ssl=True, ssl_ca_certs='C:\\Users\\chira\\anaconda3\\lib\\site-packages\\certifi\\cacert.pem'), 'Google_App_Store_Data'), 'Google_App_Store_Data')

# %%
all_records= mycollection.find()

# %%
print(all_records)
# Out:
# <pymongo.cursor.Cursor object at 0x00000157BCD402B0>

# %%
list_cursor = list(all_records)

# %%
app_data = pd.DataFrame(list_cursor)
app_data.head()
# Out:
#                         _id       \
# 0  61d5a8417b58595676734ee8   93
# 1  61d5a8417b58595676734edb   40
# 2  61d5a8417b58595676734f09  261
# 3  61d5a8417b58595676734f0c  276
# 4  61d5a8417b58595676734f47  547
#
#                                          App Name       Category  Rating  \
# 0                               Pocket Bowling 3D         Sports     3.6
# 1                                       BuradaOto       Shopping     4.9
# 2                                   Photo Collage    Photography     3.6
# 3                               Weapons Ringtones  Music & Audio     3.4
# 4  Euro Truck Simulator 2020 - Cargo Truck Driver     Simulation     3.9
#
#    Rating Count  Maximum Installs  Price  Size (Mb)   Released  Ad Supported  \
# 0           576          334144.0    0.0       22.0  3/22/2013             1
# 1           102            4103.0    0.0        3.9  8/29/2019             0
# 2          1093         2534748.0    0.0       19.0   7/3/2014             1
# 3            89           77299.0    0.0        6.7  2/14/2019             1
# 4          9443         3040422.0    0.0        NaN   6/5/2020             1
#
#    In App Purchases
# 0                 1
# 1                 0
# 2                 0
# 3                 0
# 4                 1

# %%
app_data = app_data.set_index('App Name')
app_data.head()
# Out:
#                                                                      _id       \
# App Name
# Pocket Bowling 3D                               61d5a8417b58595676734ee8   93
# BuradaOto                                       61d5a8417b58595676734edb   40
# Photo Collage                                   61d5a8417b58595676734f09  261
# Weapons Ringtones                               61d5a8417b58595676734f0c  276
# Euro Truck Simulator 2020 - Cargo Truck Driver  61d5a8417b58595676734f47  547
#
#                                                      Category  Rating  \
# App Name
# Pocket Bowling 3D                                      Sports     3.6
# BuradaOto                                            Shopping     4.9
# Photo Collage                                     Photography     3.6
# Weapons Ringtones                               Music & Audio     3.4
# Euro Truck Simulator 2020 - Cargo Truck Driver     Simulation     3.9
#
#                                                 Rating Count  \
# App Name
# Pocket Bowling 3D                                        576
# BuradaOto                                                102
# Photo Collage                                           1093
# Weapons Ringtones                                         89
# Euro Truck Simulator 2020 - Cargo Truck Driver          9443
#
#                                                 Maximum Installs  Price  \
# App Name
# Pocket Bowling 3D                                       334144.0    0.0
# BuradaOto                                                 4103.0    0.0
# Photo Collage                                          2534748.0    0.0
# Weapons Ringtones                                        77299.0    0.0
# Euro Truck Simulator 2020 - Cargo Truck Driver         3040422.0    0.0
#
#                                                 Size (Mb)   Released  \
# App Name
# Pocket Bowling 3D                                    22.0  3/22/2013
# BuradaOto                                             3.9  8/29/2019
# Photo Collage                                        19.0   7/3/2014
# Weapons Ringtones                                     6.7  2/14/2019
# Euro Truck Simulator 2020 - Cargo Truck Driver        NaN   6/5/2020
#
#                                                 Ad Supported  In App Purchases
# App Name
# Pocket Bowling 3D                                          1                 1
# BuradaOto                                                  0                 0
# Photo Collage                                              1                 0
# Weapons Ringtones                                          1                 0
# Euro Truck Simulator 2020 - Cargo Truck Driver             1                 1

# %%
app_data = app_data.drop(["_id"],axis=1)
app_data = app_data.drop(app_data.columns[0], axis=1)
app_data.head()
# Out:
#                                                      Category  Rating  \
# App Name
# Pocket Bowling 3D                                      Sports     3.6
# BuradaOto                                            Shopping     4.9
# Photo Collage                                     Photography     3.6
# Weapons Ringtones                               Music & Audio     3.4
# Euro Truck Simulator 2020 - Cargo Truck Driver     Simulation     3.9
#
#                                                 Rating Count  \
# App Name
# Pocket Bowling 3D                                        576
# BuradaOto                                                102
# Photo Collage                                           1093
# Weapons Ringtones                                         89
# Euro Truck Simulator 2020 - Cargo Truck Driver          9443
#
#                                                 Maximum Installs  Price  \
# App Name
# Pocket Bowling 3D                                       334144.0    0.0
# BuradaOto                                                 4103.0    0.0
# Photo Collage                                          2534748.0    0.0
# Weapons Ringtones                                        77299.0    0.0
# Euro Truck Simulator 2020 - Cargo Truck Driver         3040422.0    0.0
#
#                                                 Size (Mb)   Released  \
# App Name
# Pocket Bowling 3D                                    22.0  3/22/2013
# BuradaOto                                             3.9  8/29/2019
# Photo Collage                                        19.0   7/3/2014
# Weapons Ringtones                                     6.7  2/14/2019
# Euro Truck Simulator 2020 - Cargo Truck Driver        NaN   6/5/2020
#
#                                                 Ad Supported  In App Purchases
# App Name
# Pocket Bowling 3D                                          1                 1
# BuradaOto                                                  0                 0
# Photo Collage                                              1                 0
# Weapons Ringtones                                          1                 0
# Euro Truck Simulator 2020 - Cargo Truck Driver             1                 1

# %%
app_data['Rating'].median()
# Out:
# 4.2

# %%
app_data['Maximum Installs'].median()
# Out:
# 43901.5

# %%
app_data['Good_App'] = np.where((app_data['Rating']>=4.2) & (app_data['Rating Count']>=250) & (app_data['Maximum Installs']>=43901.5),1,0)
app_data.head()
# Out:
#                                                      Category  Rating  \
# App Name
# Pocket Bowling 3D                                      Sports     3.6
# BuradaOto                                            Shopping     4.9
# Photo Collage                                     Photography     3.6
# Weapons Ringtones                               Music & Audio     3.4
# Euro Truck Simulator 2020 - Cargo Truck Driver     Simulation     3.9
#
#                                                 Rating Count  \
# App Name
# Pocket Bowling 3D                                        576
# BuradaOto                                                102
# Photo Collage                                           1093
# Weapons Ringtones                                         89
# Euro Truck Simulator 2020 - Cargo Truck Driver          9443
#
#                                                 Maximum Installs  Price  \
# App Name
# Pocket Bowling 3D                                       334144.0    0.0
# BuradaOto                                                 4103.0    0.0
# Photo Collage                                          2534748.0    0.0
# Weapons Ringtones                                        77299.0    0.0
# Euro Truck Simulator 2020 - Cargo Truck Driver         3040422.0    0.0
#
#                                                 Size (Mb)   Released  \
# App Name
# Pocket Bowling 3D                                    22.0  3/22/2013
# BuradaOto                                             3.9  8/29/2019
# Photo Collage                                        19.0   7/3/2014
# Weapons Ringtones                                     6.7  2/14/2019
# Euro Truck Simulator 2020 - Cargo Truck Driver        NaN   6/5/2020
#
#                                                 Ad Supported  \
# App Name
# Pocket Bowling 3D                                          1
# BuradaOto                                                  0
# Photo Collage                                              1
# Weapons Ringtones                                          1
# Euro Truck Simulator 2020 - Cargo Truck Driver             1
#
#                                                 In App Purchases  Good_App
# App Name
# Pocket Bowling 3D                                              1         0
# BuradaOto                                                      0         0
# Photo Collage                                                  0         0
# Weapons Ringtones                                              0         0
# Euro Truck Simulator 2020 - Cargo Truck Driver                 1         0

# %%
app_data['Released'] = pd.to_datetime(app_data['Released'])
app_data.head()
# Out:
#                                                      Category  Rating  \
# App Name
# Pocket Bowling 3D                                      Sports     3.6
# BuradaOto                                            Shopping     4.9
# Photo Collage                                     Photography     3.6
# Weapons Ringtones                               Music & Audio     3.4
# Euro Truck Simulator 2020 - Cargo Truck Driver     Simulation     3.9
#
#                                                 Rating Count  \
# App Name
# Pocket Bowling 3D                                        576
# BuradaOto                                                102
# Photo Collage                                           1093
# Weapons Ringtones                                         89
# Euro Truck Simulator 2020 - Cargo Truck Driver          9443
#
#                                                 Maximum Installs  Price  \
# App Name
# Pocket Bowling 3D                                       334144.0    0.0
# BuradaOto                                                 4103.0    0.0
# Photo Collage                                          2534748.0    0.0
# Weapons Ringtones                                        77299.0    0.0
# Euro Truck Simulator 2020 - Cargo Truck Driver         3040422.0    0.0
#
#                                                 Size (Mb)   Released  \
# App Name
# Pocket Bowling 3D                                    22.0 2013-03-22
# BuradaOto                                             3.9 2019-08-29
# Photo Collage                                        19.0 2014-07-03
# Weapons Ringtones                                     6.7 2019-02-14
# Euro Truck Simulator 2020 - Cargo Truck Driver        NaN 2020-06-05
#
#                                                 Ad Supported  \
# App Name
# Pocket Bowling 3D                                          1
# BuradaOto                                                  0
# Photo Collage                                              1
# Weapons Ringtones                                          1
# Euro Truck Simulator 2020 - Cargo Truck Driver             1
#
#                                                 In App Purchases  Good_App
# App Name
# Pocket Bowling 3D                                              1         0
# BuradaOto                                                      0         0
# Photo Collage                                                  0         0
# Weapons Ringtones                                              0         0
# Euro Truck Simulator 2020 - Cargo Truck Driver                 1         0

# %%
app_data['Month_Num'] = app_data['Released'].dt.month
app_data.head()
# Out:
#                                                      Category  Rating  \
# App Name
# Pocket Bowling 3D                                      Sports     3.6
# BuradaOto                                            Shopping     4.9
# Photo Collage                                     Photography     3.6
# Weapons Ringtones                               Music & Audio     3.4
# Euro Truck Simulator 2020 - Cargo Truck Driver     Simulation     3.9
#
#                                                 Rating Count  \
# App Name
# Pocket Bowling 3D                                        576
# BuradaOto                                                102
# Photo Collage                                           1093
# Weapons Ringtones                                         89
# Euro Truck Simulator 2020 - Cargo Truck Driver          9443
#
#                                                 Maximum Installs  Price  \
# App Name
# Pocket Bowling 3D                                       334144.0    0.0
# BuradaOto                                                 4103.0    0.0
# Photo Collage                                          2534748.0    0.0
# Weapons Ringtones                                        77299.0    0.0
# Euro Truck Simulator 2020 - Cargo Truck Driver         3040422.0    0.0
#
#                                                 Size (Mb)   Released  \
# App Name
# Pocket Bowling 3D                                    22.0 2013-03-22
# BuradaOto                                             3.9 2019-08-29
# Photo Collage                                        19.0 2014-07-03
# Weapons Ringtones                                     6.7 2019-02-14
# Euro Truck Simulator 2020 - Cargo Truck Driver        NaN 2020-06-05
#
#                                                 Ad Supported  \
# App Name
# Pocket Bowling 3D                                          1
# BuradaOto                                                  0
# Photo Collage                                              1
# Weapons Ringtones                                          1
# Euro Truck Simulator 2020 - Cargo Truck Driver             1
#
#                                                 In App Purchases  Good_App  \
# App Name
# Pocket Bowling 3D                                              1         0
# BuradaOto                                                      0         0
# Photo Collage                                                  0         0
# Weapons Ringtones                                              0         0
# Euro Truck Simulator 2020 - Cargo Truck Driver                 1         0
#
#                                                 Month_Num
# App Name
# Pocket Bowling 3D                                       3
# BuradaOto                                               8
# Photo Collage                                           7
# Weapons Ringtones                                       2
# Euro Truck Simulator 2020 - Cargo Truck Driver          6

# %%
import json
#Exporting file
file_name = 'Google_App_Store_DashboardData1.js'
clean_data = app_data.to_json('Google_App_Store_DashboardData.js', orient = 'records', compression = 'infer', index = 'true')

# %%
#import json 
#clean_data = app_data.to_json(orient="split")
#parsed = json.loads(clean_data)
#json.dumps(parsed, indent=4)

# %%
from pandas import DataFrame
df = DataFrame(app_data)
#print(df)
#df_json = df.to_json(orient='split')
clean_data = df.to_json('Google_App_Store_DashboardData_new.js', orient = 'records', compression = 'infer', index = 'true')
#print(df_json)
